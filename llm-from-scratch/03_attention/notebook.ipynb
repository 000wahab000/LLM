# %% [markdown]
# # 03 — Attention
#
# ## ⚡ Predict Before You Run
#
# **Rule:** Before you execute any code cell, add a markdown cell directly above it and complete this sentence:
#
# > *"I think this will output ___ because ___."*
#
# Run it. If you were wrong — **that gap is the session's real material.** Not the video. Not the notes. The gap.
#
# ---
#
# ### 📋 Template — copy before every code cell
#
# ```
# **Prediction:** I think this will output ___ because ___.
# **Result:**     (fill after running)
# **Gap:**        (what was different and why — one sentence minimum)
# ```
#
# ---

# %% [markdown]
# ## 🔨 Sabotage Task — Two Experiments
#
# > Finish the working implementation first. Then break it twice.
#
# ---
#
# **Experiment A — Remove the causal mask**
#
# Remove the upper-triangular mask from your attention scores. Run generation on a simple sequence.
#
# 1. Does the output change? In what direction?
# 2. What specific token-prediction behaviour breaks and why?
# 3. Why is this catastrophic for autoregressive LM specifically?
#
# *Your observations (A):*
#
# ---
#
# **Experiment B — Remove the √d_k scaling**
#
# Set the scaling factor to `1.0`. Run the same forward pass.
#
# 1. What happens to the attention weight distribution? (print the raw scores before and after softmax at both settings)
# 2. Why does this cause gradient problems during training?
# 3. What does 'attention collapse' mean — did you observe it?
#
# *Your observations (B):*
